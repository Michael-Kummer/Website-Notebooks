# %% [markdown]
# # Cleaning/Imports

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from plotnine import *
import os
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
from patsy import dmatrices
from stargazer.stargazer import Stargazer
from statsmodels.graphics.factorplots import interaction_plot

os.getcwd()

#Pandas Options
pd.set_option('display.float_format', '{:,.0f}'.format)
warnings.filterwarnings("ignore")

# %%
rawdata = pd.read_csv('FraudData.csv')
rawdata = rawdata.drop(["Type de plainte recue",
                        "Categories thematiques sur la fraude et la cybercriminalite",
                        "Genre",
                        "Methode de sollicitation",
                        "Type de plainte",
                        "Langue de correspondance",
                        "Province/Etat",
                        "Pays"],axis=1)

fraudData = rawdata.rename(columns={"Numero d'identification / Number ID": "Number ID", 
                                    "Date Received / Date recue":"Date Received",
                                    "Victim Age Range / Tranche d'age des victimes":  "Age",
                                    "Number of Victims / Nombre de victimes":"Number of Victims",
                                    "Dollar Loss /pertes financieres":"Dollar Loss",
                                    "Fraud and Cybercrime Thematic Categories":"Category",
                                    "Language of Correspondence":"Language",
                                    "Solicitation Method":"SolicitMethod"})

#Clean Values
# Remove leading apostrophes
fraudData.loc[:, "Age"] = fraudData["Age"].str.replace("^'", "", regex=True)
fraudData.loc[fraudData["Age"] == "Not Available / non disponible", "Age"] = pd.NA
fraudData.loc[fraudData["Age"] == "Deceased / Décédé", "Age"] = pd.NA
fraudData.loc[fraudData["Age"] == "Business / Entreprise", "Age"] = pd.NA
fraudData.loc[fraudData["Gender"] == "Not Available", "Gender"] = pd.NA
fraudData.loc[fraudData["Gender"] == "Other", "Gender"] = pd.NA
fraudData.loc[fraudData["Gender"] == "Unknown", "Gender"] = pd.NA
fraudData.loc[fraudData["Gender"] == "Prefer not to say", "Gender"] = pd.NA
fraudData.loc[fraudData["Language"] == "Not Available", "Language"] = pd.NA
fraudData.loc[fraudData["Province/State"] == "Not Available", "Province/State"] = pd.NA
fraudData.loc[fraudData["SolicitMethod"] == "Other/unknown", "SolicitMethod"] = pd.NA
fraudData.loc[fraudData["SolicitMethod"] == "Not Available", "SolicitMethod"] = pd.NA
fraudData.loc[fraudData["Category"] == "Unknown", "Category"] = pd.NA

# Have to remove the $ and comma to get an actual integer
fraudData['Dollar Loss'] = (fraudData['Dollar Loss']
                            .str.replace('$', '', regex=False)
                            .str.replace(',', '', regex=False)
                            .astype(float)
                            .astype(int))
#Convert Date/Time to Pandas + sort
fraudData["Date Received"] = pd.to_datetime(fraudData["Date Received"])
fraudData = fraudData.sort_values("Date Received")
fraudData['Year'] = pd.DatetimeIndex(fraudData['Date Received']).year
#
fraudData.loc[fraudData["Complaint Type"] == "Attempt", "Dollar Loss"] = pd.NA


#Make two new Dataframes - One that is for individuals who were
#scammed and one for those who put in a complaint
victimData  = fraudData[fraudData["Complaint Type"]== "Victim"]
attemptData = fraudData[fraudData["Complaint Type"]== "Attempt"]

fraudData.head()
# Out:
#     Number ID Date Received Complaint Received Type        Country  \
# 0           1    2021-01-02            CAFC Website         Canada
# 51         52    2021-01-02            CAFC Website  Not Specified
# 50         51    2021-01-02            CAFC Website         Canada
# 49         50    2021-01-02            CAFC Website         Canada
# 48         49    2021-01-02            CAFC Website         Canada
#
#    Province/State        Category SolicitMethod  Gender Language      Age  \
# 0     Nova Scotia        Phishing  Text message  Female  English  30 - 39
# 51  Not Specified        Phishing  Text message    <NA>     <NA>     <NA>
# 50        Alberta  Identity Fraud          <NA>    Male  English  20 - 29
# 49         Quebec            <NA>  Text message    Male   French  40 - 49
# 48   Saskatchewan     Merchandise          <NA>    Male     <NA>  60 - 69
#
#    Complaint Type  Number of Victims  Dollar Loss  Year
# 0         Attempt                  0          NaN  2021
# 51        Attempt                  0          NaN  2021
# 50         Victim                  1            0  2021
# 49        Attempt                  0          NaN  2021
# 48         Victim                  1          222  2021

# %% [markdown]
# # Analysis

# %%
# We will be combining the lowest 3 sets
victimData["Age"].value_counts()
# Out:
# Age
# 30 - 39    31075
# 20 - 29    26298
# 40 - 49    26064
# 60 - 69    22214
# 50 - 59    21805
# 70 - 79    12360
# 10 - 19     8791
# 80 - 89     3979
# 90 - 99      500
# 1 - 9        111
# 100 +         40
# Name: count, dtype: int64

# %%
# Lists
#Combination Data

highEffortList = [
    "Romance", 
    "Investments", 
    "Foreign Money Offer", 
    "Timeshare", 
    "Recovery Pitch", 
    "Job", 
    "Bank Investigator", 
    "GRANT", 
    "Pyramid"
]

lowEffortList = [
    "Vendor Fraud", 
    "Merchandise", 
    "Extortion", 
    "Emergency (Jail, Accident, Hospital, Help)", 
    "Spear Phishing", 
    "Counterfeit Merchandise", 
    "Service", 
    "Loan", 
    "Prize", 
    "False Billing", 
    "Health", 
    "Charity / Donation", 
    "Vacation", 
    "Unauthorized Charge", 
    "Survey", 
    "Collection Agency", 
    "Spoofing", 
    "Directory", 
    "Credit Card", 
    "Telecom Fraud", 
    "Psychics", 
]

seniorAgeList = ["60 - 69", "70 - 79", "80 - 89", "90 - 99", "100 +"]
nonSeniorAgeList = ["1 - 9", "10 - 19", "20 - 29", "30 - 39", "40 - 49", "50 - 59"]

# %%
nonZeroVictim = victimData[victimData["Dollar Loss"]>0]

analysisData = nonZeroVictim.loc[
    lambda x: (x["Country"].notnull())
    & (x["Language"].notnull())
    & (x["Category"].notnull())
    & (x["Age"].notnull())
    & (x["Year"].notnull())
].dropna()


analysisData["lnDollarLoss"] = np.log(analysisData["Dollar Loss"])
analysisData["Senior"] = analysisData["Age"].isin(seniorAgeList)
analysisData = analysisData[analysisData["Gender"].isin(["Male", "Female"])]
analysisData = analysisData.rename(columns = {"Province/State":"Location"})

#Redefining and adding Vars
analysisData["Age"] = analysisData["Age"].replace({"1 - 9":"1 - 20", "10 - 19":"1 - 20"})
analysisData["Age"] = analysisData["Age"].replace({"90 - 99":"90+", "100 +":"90+"})
analysisData["Category"] = analysisData["Category"].replace({"GRANT":"Grant"})
analysisData["SolicitMethod"] = analysisData["SolicitMethod"].replace({"Internet-social network":"Social Media"})
analysisData["Category"] = analysisData["Category"].replace({"Emergency (Jail, Accident, Hospital, Help)":"Emergency"})


analysisData["EffortLevel"] = analysisData["Category"].apply(lambda x: "High Effort" if x in highEffortList else "Low Effort")

#Reindexing Year
analysisData['Year'] = analysisData['Year'] - 2021 #Start at 0

analysisData.head()
# Out:
#     Number ID Date Received Complaint Received Type Country  \
# 45         46    2021-01-02            CAFC Website  Canada
# 42         43    2021-01-02                   NCFRS  Canada
# 69         70    2021-01-02            CAFC Website  Canada
# 61         62    2021-01-02            CAFC Website  Canada
# 60         61    2021-01-02            CAFC Website  Canada
#
#                 Location      Category SolicitMethod  Gender Language  \
# 45      British Columbia  Vendor Fraud  Text message    Male  English
# 42               Alberta   Merchandise      Internet  Female  English
# 69  Prince Edward Island   Merchandise      Internet    Male  English
# 61               Alberta     Extortion  Social Media    Male  English
# 60                Quebec     Emergency         Email    Male  English
#
#         Age Complaint Type  Number of Victims  Dollar Loss  Year  \
# 45   1 - 20         Victim                  1          300     0
# 42  20 - 29         Victim                  1           50     0
# 69  30 - 39         Victim                  1       11,000     0
# 61  40 - 49         Victim                  1       24,000     0
# 60  50 - 59         Victim                  1          700     0
#
#     lnDollarLoss  Senior EffortLevel
# 45             6   False  Low Effort
# 42             4   False  Low Effort
# 69             9   False  Low Effort
# 61            10   False  Low Effort
# 60             7   False  Low Effort

# %%
analysisData["SolicitMethod"].unique()
# Out:
# array(['Text message', 'Internet', 'Social Media', 'Email', 'Direct call',
#        'Mail', 'Door to door/in person', 'Radio', 'Print', 'Television',
#        'Video Call'], dtype=object)

# %%
reg1 = smf.ols(
    'lnDollarLoss ~ Gender + Category + Age + Year', 
    data=analysisData
).fit()

reg2 = smf.ols(
    'lnDollarLoss ~ Gender + Category + Age + Year + SolicitMethod', 
    data=analysisData
).fit()

reg3 = smf.ols(
    'lnDollarLoss ~ Gender + Category + Age + Year + SolicitMethod + Senior:Category + Gender:Category',
    data=analysisData
).fit()

# stargazer = Stargazer([reg1, reg2, reg3])
# stargazer

# %% [markdown]
# # Data Charts

# %%
age_order = ['1 - 20', '20 - 29', '30 - 39', '40 - 49', '50 - 59', '60 - 69', '70 - 79', '80 - 89', '90+']

age_data = {
    '1 - 20': 1360,
    '20 - 29': 7430,
    '30 - 39': 7042,
    '40 - 49': 6357,
    '50 - 59': 5945,
    '60 - 69': 6318,
    '70 - 79': 4045,
    '80 - 89': 1250,
    '90+': 164
}

ageList = pd.DataFrame({'count': [age_data[age] for age in age_order]}, index=age_order)

def make_pretty(styler):
    styler.set_caption("Age List")
    return styler

ageList.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_62a33">
#   <caption>Age List</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62a33_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62a33_level0_row0" class="row_heading level0 row0" >1 - 20</th>
#       <td id="T_62a33_row0_col0" class="data row0 col0" >1360</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row1" class="row_heading level0 row1" >20 - 29</th>
#       <td id="T_62a33_row1_col0" class="data row1 col0" >7430</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row2" class="row_heading level0 row2" >30 - 39</th>
#       <td id="T_62a33_row2_col0" class="data row2 col0" >7042</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row3" class="row_heading level0 row3" >40 - 49</th>
#       <td id="T_62a33_row3_col0" class="data row3 col0" >6357</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row4" class="row_heading level0 row4" >50 - 59</th>
#       <td id="T_62a33_row4_col0" class="data row4 col0" >5945</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row5" class="row_heading level0 row5" >60 - 69</th>
#       <td id="T_62a33_row5_col0" class="data row5 col0" >6318</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row6" class="row_heading level0 row6" >70 - 79</th>
#       <td id="T_62a33_row6_col0" class="data row6 col0" >4045</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row7" class="row_heading level0 row7" >80 - 89</th>
#       <td id="T_62a33_row7_col0" class="data row7 col0" >1250</td>
#     </tr>
#     <tr>
#       <th id="T_62a33_level0_row8" class="row_heading level0 row8" >90+</th>
#       <td id="T_62a33_row8_col0" class="data row8 col0" >164</td>
#     </tr>
#   </tbody>
# </table>

# %%
# #Without Other
# # Get categories with 200+ observations
# category_counts = analysisData["Category"].value_counts()
# frequent_categories = category_counts[category_counts >= 200].index
# 
# # Filter the dataframe
# filtered_data = analysisData[analysisData["Category"].isin(frequent_categories)]
# 
# # Create summary table
# categoryList = filtered_data["Category"].value_counts().to_frame()
# 
# def make_pretty(styler):
#     styler.set_caption("Categories With 200+ Observations")
#     return styler
# 
# categoryList.style.pipe(make_pretty)


#With Other
# Get categories with 200+ observations
category_counts = analysisData["Category"].value_counts()
frequent_categories = category_counts[category_counts >= 200].index.tolist()

# Create a copy of the dataframe
data_with_other = analysisData.copy()

# Recode infrequent categories (including the existing "Other" category)
data_with_other["Category"] = data_with_other["Category"].apply(
    lambda x: x if x in frequent_categories else "Other"
)

# Create summary table
categoryList_with_other = data_with_other["Category"].value_counts().to_frame()

def make_pretty(styler):
    styler.set_caption("Categories (200+ Observations, Others Combined)")
    return styler

categoryList_with_other.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20b68">
#   <caption>Categories (200+ Observations, Others Combined)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20b68_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20b68_level0_row0" class="row_heading level0 row0" >Investments</th>
#       <td id="T_20b68_row0_col0" class="data row0 col0" >8896</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row1" class="row_heading level0 row1" >Merchandise</th>
#       <td id="T_20b68_row1_col0" class="data row1 col0" >7488</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row2" class="row_heading level0 row2" >Service</th>
#       <td id="T_20b68_row2_col0" class="data row2 col0" >4214</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row3" class="row_heading level0 row3" >Vendor Fraud</th>
#       <td id="T_20b68_row3_col0" class="data row3 col0" >3299</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row4" class="row_heading level0 row4" >Job</th>
#       <td id="T_20b68_row4_col0" class="data row4 col0" >2874</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row5" class="row_heading level0 row5" >Romance</th>
#       <td id="T_20b68_row5_col0" class="data row5 col0" >2528</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row6" class="row_heading level0 row6" >Bank Investigator</th>
#       <td id="T_20b68_row6_col0" class="data row6 col0" >1957</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row7" class="row_heading level0 row7" >Counterfeit Merchandise</th>
#       <td id="T_20b68_row7_col0" class="data row7 col0" >1823</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row8" class="row_heading level0 row8" >Extortion</th>
#       <td id="T_20b68_row8_col0" class="data row8 col0" >1582</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row9" class="row_heading level0 row9" >Emergency</th>
#       <td id="T_20b68_row9_col0" class="data row9 col0" >1562</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row10" class="row_heading level0 row10" >Other</th>
#       <td id="T_20b68_row10_col0" class="data row10 col0" >803</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row11" class="row_heading level0 row11" >Spear Phishing</th>
#       <td id="T_20b68_row11_col0" class="data row11 col0" >784</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row12" class="row_heading level0 row12" >Loan</th>
#       <td id="T_20b68_row12_col0" class="data row12 col0" >677</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row13" class="row_heading level0 row13" >Prize</th>
#       <td id="T_20b68_row13_col0" class="data row13 col0" >621</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row14" class="row_heading level0 row14" >Recovery Pitch</th>
#       <td id="T_20b68_row14_col0" class="data row14 col0" >448</td>
#     </tr>
#     <tr>
#       <th id="T_20b68_level0_row15" class="row_heading level0 row15" >Grant</th>
#       <td id="T_20b68_row15_col0" class="data row15 col0" >355</td>
#     </tr>
#   </tbody>
# </table>

# %%
genderList = analysisData["Gender"].value_counts()
genderList = genderList.to_frame()

def make_pretty(styler):
    styler.set_caption("Age List")
    return styler

genderList.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e07e">
#   <caption>Age List</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e07e_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e07e_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_3e07e_row0_col0" class="data row0 col0" >20080</td>
#     </tr>
#     <tr>
#       <th id="T_3e07e_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_3e07e_row1_col0" class="data row1 col0" >19831</td>
#     </tr>
#   </tbody>
# </table>

# %%
# First get the counts
method_counts = analysisData["SolicitMethod"].value_counts()

# Get methods that appear at least 100 times
frequent_methods = method_counts[method_counts >= 100].index.tolist()

# Recode the SolicitMethod column
# Replace infrequent methods with "Other" or remove them
otherMethods = []
analysisData["SolicitMethod"] = analysisData["SolicitMethod"].apply(
    lambda x: x if x in frequent_methods else "Other" 
)

# Now create your summary
methodList = analysisData["SolicitMethod"].value_counts().to_frame()

def make_pretty(styler):
    styler.set_caption("Methods Above 100 Observations (Others Combined)")
    return styler
methodList = methodList.rename_axis(None)
methodList.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2704">
#   <caption>Methods Above 100 Observations (Others Combined)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2704_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2704_level0_row0" class="row_heading level0 row0" >Social Media</th>
#       <td id="T_d2704_row0_col0" class="data row0 col0" >14792</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row1" class="row_heading level0 row1" >Internet</th>
#       <td id="T_d2704_row1_col0" class="data row1 col0" >12529</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row2" class="row_heading level0 row2" >Direct call</th>
#       <td id="T_d2704_row2_col0" class="data row2 col0" >6642</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row3" class="row_heading level0 row3" >Email</th>
#       <td id="T_d2704_row3_col0" class="data row3 col0" >3076</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row4" class="row_heading level0 row4" >Text message</th>
#       <td id="T_d2704_row4_col0" class="data row4 col0" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row5" class="row_heading level0 row5" >Door to door/in person</th>
#       <td id="T_d2704_row5_col0" class="data row5 col0" >699</td>
#     </tr>
#     <tr>
#       <th id="T_d2704_level0_row6" class="row_heading level0 row6" >Other</th>
#       <td id="T_d2704_row6_col0" class="data row6 col0" >150</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reanalysis

# %%
analysisData[analysisData["Category"] == "Emergency (Jail, Accident, Hospital, Help)"]["SolicitMethod"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Model 1: Base Vulnerability Model

# %%
model1 = smf.ols('lnDollarLoss ~ C(Category, Treatment(reference="Emergency")) + Gender + Senior + C(SolicitMethod, Treatment(reference="Direct call")) + Year', data=analysisData).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           lnDollarLoss   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.430
# Method:                 Least Squares   F-statistic:                     753.9
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):               0.00
# Time:                        16:02:09   Log-Likelihood:                -79340.
# No. Observations:               39911   AIC:                         1.588e+05
# Df Residuals:                   39870   BIC:                         1.591e+05
# Df Model:                          40
# Covariance Type:            nonrobust
# ==================================================================================================================================================
#                                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                          7.8166      0.052    150.324      0.000       7.715       7.919
# C(Category, Treatment(reference="Emergency"))[T.Bank Investigator]                 0.2610      0.061      4.250      0.000       0.141       0.381
# C(Category, Treatment(reference="Emergency"))[T.Charity / Donation]               -2.3298      0.287     -8.111      0.000      -2.893      -1.767
# C(Category, Treatment(reference="Emergency"))[T.Collection Agency]                -1.2821      0.389     -3.292      0.001      -2.045      -0.519
# C(Category, Treatment(reference="Emergency"))[T.Counterfeit Merchandise]          -2.3976      0.066    -36.057      0.000      -2.528      -2.267
# C(Category, Treatment(reference="Emergency"))[T.Credit Card]                       0.2331      0.886      0.263      0.792      -1.503       1.970
# C(Category, Treatment(reference="Emergency"))[T.Directory]                         0.6155      1.251      0.492      0.623      -1.836       3.067
# C(Category, Treatment(reference="Emergency"))[T.Extortion]                         0.0496      0.065      0.759      0.448      -0.078       0.178
# C(Category, Treatment(reference="Emergency"))[T.False Billing]                    -1.5181      0.146    -10.387      0.000      -1.805      -1.232
# C(Category, Treatment(reference="Emergency"))[T.Foreign Money Offer]               2.2305      0.205     10.892      0.000       1.829       2.632
# C(Category, Treatment(reference="Emergency"))[T.Grant]                             0.3523      0.107      3.305      0.001       0.143       0.561
# C(Category, Treatment(reference="Emergency"))[T.Health]                           -1.5378      0.535     -2.873      0.004      -2.587      -0.489
# C(Category, Treatment(reference="Emergency"))[T.Incomplete]                       -0.8698      0.372     -2.341      0.019      -1.598      -0.142
# C(Category, Treatment(reference="Emergency"))[T.Investments]                       1.9589      0.054     36.548      0.000       1.854       2.064
# C(Category, Treatment(reference="Emergency"))[T.Job]                               0.7514      0.061     12.386      0.000       0.632       0.870
# C(Category, Treatment(reference="Emergency"))[T.Loan]                             -0.2414      0.084     -2.861      0.004      -0.407      -0.076
# C(Category, Treatment(reference="Emergency"))[T.Merchandise]                      -1.4198      0.055    -25.637      0.000      -1.528      -1.311
# C(Category, Treatment(reference="Emergency"))[T.Other]                            -0.0820      0.142     -0.578      0.563      -0.360       0.196
# C(Category, Treatment(reference="Emergency"))[T.Prize]                            -0.4713      0.084     -5.592      0.000      -0.636      -0.306
# C(Category, Treatment(reference="Emergency"))[T.Psychics]                         -1.0875      0.280     -3.882      0.000      -1.637      -0.538
# C(Category, Treatment(reference="Emergency"))[T.Pyramid]                           0.1758      0.199      0.883      0.377      -0.214       0.566
# C(Category, Treatment(reference="Emergency"))[T.Recovery Pitch]                    0.7169      0.095      7.524      0.000       0.530       0.904
# C(Category, Treatment(reference="Emergency"))[T.Romance]                           1.9892      0.062     31.922      0.000       1.867       2.111
# C(Category, Treatment(reference="Emergency"))[T.Service]                          -0.8638      0.055    -15.577      0.000      -0.972      -0.755
# C(Category, Treatment(reference="Emergency"))[T.Spear Phishing]                   -0.3307      0.084     -3.952      0.000      -0.495      -0.167
# C(Category, Treatment(reference="Emergency"))[T.Spoofing]                         -3.6683      1.768     -2.075      0.038      -7.134      -0.202
# C(Category, Treatment(reference="Emergency"))[T.Survey]                           -3.3208      0.792     -4.191      0.000      -4.874      -1.768
# C(Category, Treatment(reference="Emergency"))[T.Telecom Fraud]                    -3.7074      1.022     -3.629      0.000      -5.710      -1.705
# C(Category, Treatment(reference="Emergency"))[T.Timeshare]                         1.8302      0.210      8.696      0.000       1.418       2.243
# C(Category, Treatment(reference="Emergency"))[T.Unauthorized Charge]              -3.3413      0.389     -8.593      0.000      -4.103      -2.579
# C(Category, Treatment(reference="Emergency"))[T.Vacation]                         -0.1909      0.252     -0.757      0.449      -0.685       0.303
# C(Category, Treatment(reference="Emergency"))[T.Vendor Fraud]                     -1.1899      0.060    -19.738      0.000      -1.308      -1.072
# Gender[T.Male]                                                                     0.0924      0.018      5.115      0.000       0.057       0.128
# Senior[T.True]                                                                     0.2923      0.021     13.680      0.000       0.250       0.334
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Door to door/in person]     0.3069      0.074      4.169      0.000       0.163       0.451
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Email]                     -0.6816      0.046    -14.827      0.000      -0.772      -0.591
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Internet]                  -0.6340      0.035    -18.307      0.000      -0.702      -0.566
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Other]                     -0.7435      0.148     -5.025      0.000      -1.034      -0.454
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Social Media]              -0.7875      0.035    -22.474      0.000      -0.856      -0.719
# C(SolicitMethod, Treatment(reference="Direct call"))[T.Text message]              -0.3664      0.050     -7.274      0.000      -0.465      -0.268
# Year                                                                               0.1991      0.008     23.635      0.000       0.183       0.216
# ==============================================================================
# Omnibus:                      817.777   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1332.104
# Skew:                          -0.197   Prob(JB):                    5.46e-290
# Kurtosis:                       3.804   Cond. No.                         421.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Model 2: Interaction

# %%
model2 = smf.ols('lnDollarLoss ~ C(Category, Treatment(reference="Emergency")) + Gender*Senior + C(SolicitMethod, Treatment(reference="Direct call")) + Year', data=analysisData).fit()

# %% [markdown]
# ## Model 3: Solicitation effectiveness model

# %%
model3 = smf.ols('lnDollarLoss ~ C(Category, Treatment(reference="Emergency")) + Gender + Senior + Year + C(SolicitMethod, Treatment(reference="Direct call")) + C(SolicitMethod, Treatment(reference="Direct call")):Senior + C(SolicitMethod, Treatment(reference="Direct call")):Gender', data=analysisData).fit()

# %%
# Create Stargazer instance
stargazer = Stargazer([model1, model2, model3])

stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: lnDollarLoss</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Bank Investigator]</td><td>0.261<sup>***</sup></td><td>0.262<sup>***</sup></td><td>0.279<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.061)</td><td>(0.061)</td><td>(0.063)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Charity / Donation]</td><td>-2.330<sup>***</sup></td><td>-2.327<sup>***</sup></td><td>-2.321<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.287)</td><td>(0.287)</td><td>(0.288)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Collection Agency]</td><td>-1.282<sup>***</sup></td><td>-1.280<sup>***</sup></td><td>-1.237<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.389)</td><td>(0.389)</td><td>(0.391)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Counterfeit Merchandise]</td><td>-2.398<sup>***</sup></td><td>-2.395<sup>***</sup></td><td>-2.373<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.066)</td><td>(0.067)</td><td>(0.068)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Credit Card]</td><td>0.233<sup></sup></td><td>0.232<sup></sup></td><td>0.305<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.886)</td><td>(0.886)</td><td>(0.887)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Directory]</td><td>0.616<sup></sup></td><td>0.623<sup></sup></td><td>0.703<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.251)</td><td>(1.251)</td><td>(1.250)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Extortion]</td><td>0.050<sup></sup></td><td>0.051<sup></sup></td><td>0.094<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.065)</td><td>(0.065)</td><td>(0.069)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.False Billing]</td><td>-1.518<sup>***</sup></td><td>-1.517<sup>***</sup></td><td>-1.463<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.146)</td><td>(0.146)</td><td>(0.147)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Foreign Money Offer]</td><td>2.231<sup>***</sup></td><td>2.235<sup>***</sup></td><td>2.231<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.205)</td><td>(0.205)</td><td>(0.205)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Grant]</td><td>0.352<sup>***</sup></td><td>0.353<sup>***</sup></td><td>0.379<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.107)</td><td>(0.107)</td><td>(0.109)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Health]</td><td>-1.538<sup>***</sup></td><td>-1.534<sup>***</sup></td><td>-1.486<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.535)</td><td>(0.535)</td><td>(0.535)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Incomplete]</td><td>-0.870<sup>**</sup></td><td>-0.868<sup>**</sup></td><td>-0.835<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.372)</td><td>(0.372)</td><td>(0.372)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Investments]</td><td>1.959<sup>***</sup></td><td>1.962<sup>***</sup></td><td>1.986<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.054)</td><td>(0.054)</td><td>(0.056)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Job]</td><td>0.751<sup>***</sup></td><td>0.754<sup>***</sup></td><td>0.767<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.061)</td><td>(0.061)</td><td>(0.063)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Loan]</td><td>-0.241<sup>***</sup></td><td>-0.239<sup>***</sup></td><td>-0.211<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.084)</td><td>(0.084)</td><td>(0.086)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Merchandise]</td><td>-1.420<sup>***</sup></td><td>-1.417<sup>***</sup></td><td>-1.401<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.055)</td><td>(0.056)</td><td>(0.057)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Other]</td><td>-0.082<sup></sup></td><td>-0.080<sup></sup></td><td>-0.054<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.142)</td><td>(0.142)</td><td>(0.142)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Prize]</td><td>-0.471<sup>***</sup></td><td>-0.470<sup>***</sup></td><td>-0.474<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.084)</td><td>(0.084)</td><td>(0.085)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Psychics]</td><td>-1.088<sup>***</sup></td><td>-1.086<sup>***</sup></td><td>-1.081<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.280)</td><td>(0.280)</td><td>(0.280)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Pyramid]</td><td>0.176<sup></sup></td><td>0.178<sup></sup></td><td>0.208<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.199)</td><td>(0.199)</td><td>(0.199)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Recovery Pitch]</td><td>0.717<sup>***</sup></td><td>0.720<sup>***</sup></td><td>0.749<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.095)</td><td>(0.095)</td><td>(0.096)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Romance]</td><td>1.989<sup>***</sup></td><td>1.991<sup>***</sup></td><td>2.015<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.062)</td><td>(0.062)</td><td>(0.065)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Service]</td><td>-0.864<sup>***</sup></td><td>-0.862<sup>***</sup></td><td>-0.830<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.055)</td><td>(0.056)</td><td>(0.058)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Spear Phishing]</td><td>-0.331<sup>***</sup></td><td>-0.328<sup>***</sup></td><td>-0.301<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.084)</td><td>(0.084)</td><td>(0.085)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Spoofing]</td><td>-3.668<sup>**</sup></td><td>-3.674<sup>**</sup></td><td>-3.588<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.768)</td><td>(1.768)</td><td>(1.767)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Survey]</td><td>-3.321<sup>***</sup></td><td>-3.315<sup>***</sup></td><td>-3.314<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.792)</td><td>(0.792)</td><td>(0.793)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Telecom Fraud]</td><td>-3.707<sup>***</sup></td><td>-3.708<sup>***</sup></td><td>-3.677<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.022)</td><td>(1.022)</td><td>(1.021)</td></tr>
# <tr><td style="text-align:left">C(Category, Treatment(reference="Emergency"))[T.Timeshare]</td><td>1.830<sup>***</sup></t

# %% [markdown]
# # Graphs

# %%
# Age Effects Graph - bar chart
plt.figure(figsize=(10, 6))
age_data = age_coefs.copy()
age_data['Percentage'] = age_data['Coefficient'].apply(lambda x: 0 if x == 0 else (np.exp(x) - 1) * 100)
sns.barplot(x='Age Group', y='Percentage', data=age_data)
plt.title('Percentage Increase in Fraud Dollar Loss by Age Group')
plt.ylabel('% Increase vs Under 20')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('age_effects.png', dpi=300)

# Category Effects - horizontal bar chart for top 10 categories
categories = cat_coefs.copy()
categories['Percentage'] = categories['Coefficient'].apply(lambda x: (np.exp(x) - 1) * 100)
top10 = categories.sort_values('Percentage', ascending=False).head(10)

plt.figure(figsize=(12, 8))
sns.barplot(y='Category', x='Percentage', data=top10)
plt.title('Top 10 Fraud Categories by % Difference in Dollar Loss')
plt.xlabel('% Difference from Identity Theft')
plt.tight_layout()
plt.savefig('top_categories.png', dpi=300)

# Senior Interactions - Horizontal bar chart
sig_senior = significant_senior.copy()
sig_senior['Percentage'] = sig_senior['Coefficient'].apply(lambda x: (np.exp(x) - 1) * 100)
sig_senior = sig_senior.sort_values('Percentage', ascending=True)  # Ascending for horizontal plot

plt.figure(figsize=(12, 8))
sns.barplot(y='Category', x='Percentage', data=sig_senior)
plt.axvline(x=0, color='black', linestyle='-', alpha=0.7)
plt.title('Impact of Senior Status on Fraud Loss by Category')
plt.xlabel('% Change in Fraud Loss for Seniors')
plt.tight_layout()
plt.savefig('senior_effects.png', dpi=300)
